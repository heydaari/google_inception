# %% [markdown]
# # InceptionV1 ( GoogLeNet) implementation with Tensorflow-Keras
#
# * Developed by Mohammad Hassan Heydari
# * Based on the paper *Going Deeper with Convolutions*
# * Trained on 2% of CIFAR10 datset due to limitations :(

# %%
# importing necessary libraries

import keras
from keras.layers import Layer
import keras.backend as K
import tensorflow as tf
from keras.datasets import cifar10
import math

from keras.models import Model
from keras.layers import Conv2D, MaxPool2D, \
    Dropout, Dense, Input, concatenate, \
    GlobalAveragePooling2D, AveragePooling2D, \
    Flatten

import numpy as np
from keras.datasets import cifar10
from keras import backend as K

from keras.optimizers import SGD
from keras.callbacks import LearningRateScheduler

# %%
def load_cifar10_data():

    num_classes = 10
    # Load cifar10 training and validation sets
    (X_train, Y_train), (X_valid, Y_valid) = cifar10.load_data()



    X_train = X_train.astype('float32')
    X_valid = X_valid.astype('float32')

    # preprocess data
    X_train = X_train / 255.0
    X_valid = X_valid / 255.0

    return X_train, Y_train, X_valid, Y_valid

X_train, y_train, X_test, y_test = load_cifar10_data()

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 4s 0us/step
# (50000, 32, 32, 3)
# (50000, 1)
# (10000, 32, 32, 3)
# (10000, 1)

# %%
from cv2 import resize
# Resize training images
X_train = np.array([resize(img, (224, 224)) for img in X_train[:1000]])
X_test = np.array([resize(img, (224, 224)) for img in X_test[:200]])

y_train = y_train[:1000]
y_test = y_test[:200]

# %%
# inception block
def inception_module(input,
                     filters_1x1,
                     filters_3x3_reduce,
                     filters_3x3,
                     filters_5x5_reduce,
                     filters_5x5,
                     filters_pool_proj,
                     name=None):
    conv_1x1 = Conv2D(filters_1x1, (1, 1), padding='same', activation='relu')(input)

    conv_3x3 = Conv2D(filters_3x3_reduce, (1, 1), padding='same', activation='relu')(input)
    conv_3x3 = Conv2D(filters_3x3, (3, 3), padding='same', activation='relu')(conv_3x3)

    conv_5x5 = Conv2D(filters_5x5_reduce, (1, 1), padding='same', activation='relu')(input)
    conv_5x5 = Conv2D(filters_5x5, (5, 5), padding='same', activation='relu')(conv_5x5)

    pool_proj = MaxPool2D((3, 3), strides=(1, 1), padding='same')(input)
    pool_proj = Conv2D(filters_pool_proj, (1, 1), padding='same', activation='relu')(pool_proj)


    # remember , use concatenate layer, Not concatenate.Concatenate
    output = concatenate([conv_1x1, conv_3x3, conv_5x5, pool_proj],axis=3, name=name)

    return output

input_layer = Input(shape=(224, 224, 3))

x = Conv2D(64, (7, 7), padding='same', strides=(2, 2), activation='relu', name='conv_1_7x7/2')(input_layer)
x = MaxPool2D((3, 3), padding='same', strides=(2, 2), name='max_pool_1_3x3/2')(x)
x = Conv2D(64, (1, 1), padding='same', strides=(1, 1), activation='relu', name='conv_2a_3x3/1')(x)
x = Conv2D(192, (3, 3), padding='same', strides=(1, 1), activation='relu', name='conv_2b_3x3/1')(x)
x = MaxPool2D((3, 3), padding='same', strides=(2, 2), name='max_pool_2_3x3/2')(x)

x = inception_module(x,
                     filters_1x1=16,
                     filters_3x3_reduce=16,
                     filters_3x3=16,
                     filters_5x5_reduce=16,
                     filters_5x5=16,
                     filters_pool_proj=16,
                     name='inception_3a')

x = inception_module(x,
                     filters_1x1=32,
                     filters_3x3_reduce=32,
                     filters_3x3=32,
                     filters_5x5_reduce=32,
                     filters_5x5=32,
                     filters_pool_proj=32,
                     name='inception_3b')

x = MaxPool2D((3, 3), padding='same', strides=(2, 2), name='max_pool_3_3x3/2')(x)

x = inception_module(x,
                     filters_1x1=32,
                     filters_3x3_reduce=32,
                     filters_3x3=32,
                     filters_5x5_reduce=32,
                     filters_5x5=32,
                     filters_pool_proj=32,
                     name='inception_4a')

# getting out of the network , first output
output_1 = AveragePooling2D((5, 5), strides=3)(x)
output_1 = Conv2D(64, (1, 1), padding='same', activation='relu')(output_1)
output_1 = Flatten()(output_1)
output_1 = Dense(64, activation='relu')(output_1)
output_1 = Dropout(0.2)(output_1)
output_1 = Dense(10, activation='softmax', name='output_1')(output_1)

x = inception_module(x,
                     filters_1x1=32,
                     filters_3x3_reduce=32,
                     filters_3x3=32,
                     filters_5x5_reduce=32,
                     filters_5x5=32,
                     filters_pool_proj=32,
                     name='inception_4b')

x = inception_module(x,
                     filters_1x1=32,
                     filters_3x3_reduce=32,
                     filters_3x3=32,
                     filters_5x5_reduce=32,
                     filters_5x5=32,
                     filters_pool_proj=32,
                     name='inception_4c')

x = inception_module(x,
                     filters_1x1=32,
                     filters_3x3_reduce=32,
                     filters_3x3=32,
                     filters_5x5_reduce=32,
                     filters_5x5=32,
                     filters_pool_proj=32,
                     name='inception_4d')

# getting out of the network , second output
output_2 = AveragePooling2D((5, 5), strides=3)(x)
output_2 = Conv2D(64, (1, 1), padding='same', activation='relu')(output_2)
output_2 = Flatten()(output_2)
output_2 = Dense(64, activation='relu')(output_2)
output_2 = Dropout(0.2)(output_2)
output_2 = Dense(10, activation='softmax', name='auxilliary_output_2')(output_2)

x = inception_module(x,
                     filters_1x1=32,
                     filters_3x3_reduce=32,
                     filters_3x3=32,
                     filters_5x5_reduce=32,
                     filters_5x5=32,
                     filters_pool_proj=32,
                     name='inception_4e')

x = MaxPool2D((3, 3), padding='same', strides=(2, 2), name='max_pool_4_3x3/2')(x)

x = inception_module(x,
                     filters_1x1=256,
                     filters_3x3_reduce=160,
                     filters_3x3=320,
                     filters_5x5_reduce=32,
                     filters_5x5=128,
                     filters_pool_proj=128,
                     name='inception_5a')

x = inception_module(x,
                     filters_1x1=384,
                     filters_3x3_reduce=192,
                     filters_3x3=384,
                     filters_5x5_reduce=48,
                     filters_5x5=128,
                     filters_pool_proj=128,
                     name='inception_5b')

x = GlobalAveragePooling2D(name='avg_pool_5_3x3/1')(x)

x = Dropout(0.4)(x)

# final output
output_3 = Dense(10, activation='softmax', name='output')(x)

# %%
model = Model(input_layer, [output_3, output_1, output_2], name='inception_v1')

model.summary()
# Out:
# Model: "inception_v1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv_1_7x7/2 (Conv2D)       (None, 112, 112, 64)         9472      ['input_1[0][0]']
#
#  max_pool_1_3x3/2 (MaxPooli  (None, 56, 56, 64)           0         ['conv_1_7x7/2[0][0]']
#  ng2D)
#
#  conv_2a_3x3/1 (Conv2D)      (None, 56, 56, 64)           4160      ['max_pool_1_3x3/2[0][0]']
#
#  conv_2b_3x3/1 (Conv2D)      (None, 56, 56, 192)          110784    ['conv_2a_3x3/1[0][0]']
#
#  max_pool_2_3x3/2 (MaxPooli  (None, 28, 28, 192)          0         ['conv_2b_3x3/1[0][0]']
#  ng2D)
#
#  conv2d_1 (Conv2D)           (None, 28, 28, 16)           3088      ['max_pool_2_3x3/2[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 28, 28, 16)           3088      ['max_pool_2_3x3/2[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 28, 28, 192)          0         ['max_pool_2_3x3/2[0][0]']
#  D)
#
#  conv2d (Conv2D)             (None, 28, 28, 16)           3088      ['max_pool_2_3x3/2[0][0]']
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 16)           2320      ['conv2d_1[0][0]']
#
#  conv2d_4 (Conv2D)           (None, 28, 28, 16)           6416      ['conv2d_3[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 28, 28, 16)           3088      ['max_pooling2d[0][0]']
#
#  inception_3a (Concatenate)  (None, 28, 28, 64)           0         ['conv2d[0][0]',
#                                                                      'conv2d_2[0][0]',
#                                                                      'conv2d_4[0][0]',
#                                                                      'conv2d_5[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 28, 28, 32)           2080      ['inception_3a[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 28, 28, 32)           2080      ['inception_3a[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 28, 28, 64)           0         ['inception_3a[0][0]']
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 28, 28, 32)           2080      ['inception_3a[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 28, 28, 32)           9248      ['conv2d_7[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 28, 28, 32)           25632     ['conv2d_9[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 28, 28, 32)           2080      ['max_pooling2d_1[0][0]']
#
#  inception_3b (Concatenate)  (None, 28, 28, 128)          0         ['conv2d_6[0][0]',
#                                                                      'conv2d_8[0][0]',
#                                                                      'conv2d_10[0][0]',
#                                                                      'conv2d_11[0][0]']
#
#  max_pool_3_3x3/2 (MaxPooli  (None, 14, 14, 128)          0         ['inception_3b[0][0]']
#  ng2D)
#
#  conv2d_13 (Conv2D)          (None, 14, 14, 32)           4128      ['max_pool_3_3x3/2[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 14, 14, 32)           4128      ['max_pool_3_3x3/2[0][0]']
#
#  max_pooling2d_2 (MaxPoolin  (None, 14, 14, 128)          0         ['max_pool_3_3x3/2[0][0]']
#  g2D)
#
#  conv2d_12 (Conv2D)          (None, 14, 14, 32)           4128      ['max_pool_3_3x3/2[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 14, 14, 32)           9248      ['conv2d_13[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 14, 14, 32)           25632     ['conv2d_15[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 14, 14, 32)           4128      ['max_pooling2d_2[0][0]']
#
#  inception_4a (Concatenate)  (None, 14, 14, 128)          0         ['conv2d_12[0][0]',
#                                                                      'conv2d_14[0][0]',
#                                                                      'conv2d_16[0][0]',
#                                                                      'conv2d_17[0][0]']
#
#  conv2d_20 (Conv2D)          (None, 14, 14, 32)           4128      ['inception_4a[0][0]']
#
#  conv2d_22 (Conv2D)          (None, 14, 14, 32)           4128      ['inception_4a[0][0]']
#
#  max_pooling2d_3 (MaxPoolin  (None, 14, 14, 128)          0         ['inception_4a[0][0]']
#  g2D)
#
#  conv2d_19 (Conv2D)          (None, 14, 14, 32)           4128      ['inception_4a[0][0]']
#
#  conv2d_21 (Conv2D)          (None, 14, 14, 32)           9248      ['conv2d_20[0][0]']
#
#  conv2d_23 (Conv2D)          (None, 14, 14, 32)           25632     ['conv2d_22[0][0]']
#
#  conv2d_24 (Conv2D)          (None, 14, 14, 32)           4128      ['max_pooling2d_3[0][0]']
#
#  inception_4b (Concatenate)  (None, 14, 14, 128)          0         ['conv2d_19[0][0]',
#                                                                      'conv2d_21[0][0]',
#                                                                      'conv2d_23[0][0]',
#                                                                      'conv2d_24[0][0]']
#
#  conv2d_26 (Conv2D)          (None, 14, 14, 32)           4128      ['inception_4b[0][0]']
#
#  conv2d_28 (Conv2D)          (None, 14, 14, 32)           4128      ['inception_4b[0][0]']
#
#  max_pooling2d_4 (MaxPoolin  (None, 14, 14, 128)          0         ['inception_4b[0][0]']
#  g2D)
#
#  conv2d_25 (Conv2D)          (None, 14, 14, 32)           4128      ['inception_4b[0][0]']
#
#  conv2d_27 (Conv2D)          (None, 14, 14, 32)           9248      ['conv2d_26[0][0]']
#
#  conv2d_29 (Conv2D)          (None, 14, 14, 32)           25632     ['conv2d_28[0][0]']
#
#  conv2d_30 (Conv2D)          (None, 14, 14, 32)           4128      ['max_pooling2d_4[0][0]']
#
#  inception_4c (Concatenate)  (None, 14, 14, 128)          0         ['conv2d_25[0][0]',
#                                                                      'conv2d_27[0][0]',
#                                                                      'conv2d_29[0][0]',
#                                                                      'conv2d_30[0][0]']
#
#  conv2d_32 (Conv2D)          (None, 14, 14, 32)           4128      ['inception_4c[0][0]']
#
#  conv2d_34 (Conv2D)          (None, 14, 14, 32)           4128      ['inception_4c[0][0]']
#
#  max_pooling2d_5 (MaxPoolin  (None, 14, 14, 128)          0         ['inception_4c[0][0]']
#  g2D)
#
#  conv2d_31 (Conv2D)          (None, 14, 14, 32)           4128      ['inception_4c[0][0]']
#
#  conv2d_33 (Conv2D)          (None, 14, 14, 32)           9248      ['conv2d_32[0][0]']
#
#  conv2d_35 (Conv2D)          (None, 14, 14, 32)           25632     ['conv2d_34[0][0]']
#
#  conv2d_36 (Conv2D)          (None, 14, 14, 32)           4128      ['max_pooling2d_5[0][0]']
#
#  inception_4d (Concatenate)  (None, 14, 14, 128)          0         ['conv2d_31[0][0]',
#                                                                      'conv2d_33[0][0]',
#                                                                      'conv2d_35[0][0]',
#                                                                      'conv2d_36[0][0]']
#
#  conv2d_39 (Conv2D)          (None, 14, 14, 32)           4128      ['inception_4d[0][0]']
#
#  conv2d_41 (Conv2D)          (None, 14, 14, 32)           4128      ['inception_4d[0][0]']
#
#  max_pooling2d_6 (MaxPoolin  (None, 14, 14, 128)          0         ['inception_4d[0][0]']
#  g2D)
#
#  conv2d_38 (Conv2D)          (None, 14, 14, 32)           4128      ['inception_4d[0][0]']
#
#  conv2d_40 (Conv2D)          (None, 14, 14, 32)           9248      ['conv2d_39[0][0]']
#
#  conv2d_42 (Conv2D)          (None, 14, 14, 32)           25632     ['conv2d_41[0][0]']
#
#  conv2d_43 (Conv2D)          (None, 14, 14, 32)           4128      ['max_pooling2d_6[0][0]']
#
#  inception_4e (Concatenate)  (None, 14, 14, 128)          0         ['conv2d_38[0][0]',
#                                                                      'conv2d_40[0][0]',
#                                                                      'conv2d_42[0][0]',
#                                                                      'conv2d_43[0][0]']
#
#  max_pool_4_3x3/2 (MaxPooli  (None, 7, 7, 128)            0         ['inception_4e[0][0]']
#  ng2D)
#
#  conv2d_45 (Conv2D)          (None, 7, 7, 160)            20640     ['max_pool_4_3x3/2[0][0]']
#
#  conv2d_47 (Conv2D)          (None, 7, 7, 32)             4128      ['max_pool_4_3x3/2[0][0]']
#
#  max_pooling2d_7 (MaxPoolin  (None, 7, 7, 128)            0         ['max_pool_4_3x3/2[0][0]']
#  g2D)
#
#  conv2d_44 (Conv2D)          (None, 7, 7, 256)            33024     ['max_pool_4_3x3/2[0][0]']
#
#  conv2d_46 (Conv2D)          (None, 7, 7, 320)            461120    ['conv2d_45[0][0]']
#
#  conv2d_48 (Conv2D)          (None, 7, 7, 128)            102528    ['conv2d_47[0][0]']
#
#  conv2d_49 (Conv2D)          (None, 7, 7, 128)            16512     ['max_pooling2d_7[0][0]']
#
#  inception_5a (Concatenate)  (None, 7, 7, 832)            0         ['conv2d_44[0][0]',
#                                                                      'conv2d_46[0][0]',
#                                                                      'conv2d_48[0][0]',
#                                                                      'conv2d_49[0][0]']
#
#  conv2d_51 (Conv2D)          (None, 7, 7, 192)            159936    ['inception_5a[0][0]']
#
#  conv2d_53 (Conv2D)          (None, 7, 7, 48)             39984     ['inception_5a[0][0]']
#
#  max_pooling2d_8 (MaxPoolin  (None, 7, 7, 832)            0         ['inception_5a[0][0]']
#  g2D)
#
#  average_pooling2d (Average  (None, 4, 4, 128)            0         ['inception_4a[0][0]']
#  Pooling2D)
#
#  average_pooling2d_1 (Avera  (None, 4, 4, 128)            0         ['inception_4d[0][0]']
#  gePooling2D)
#
#  conv2d_50 (Conv2D)          (None, 7, 7, 384)            319872    ['inception_5a[0][0]']
#
#  conv2d_52 (Conv2D)          (None, 7, 7, 384)            663936    ['conv2d_51[0][0]']
#
#  conv2d_54 (Conv2D)          (None, 7, 7, 128)            153728    ['conv2d_53[0][0]']
#
#  conv2d_55 (Conv2D)          (None, 7, 7, 128)            106624    ['max_pooling2d_8[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 4, 4, 64)             8256      ['average_pooling2d[0][0]']
#
#  conv2d_37 (Conv2D)          (None, 4, 4, 64)             8256      ['average_pooling2d_1[0][0]']
#
#  inception_5b (Concatenate)  (None, 7, 7, 1024)           0         ['conv2d_50[0][0]',
#                                                                      'conv2d_52[0][0]',
#                                                                      'conv2d_54[0][0]',
#                                                                      'conv2d_55[0][0]']
#
#  flatten (Flatten)           (None, 1024)                 0         ['conv2d_18[0][0]']
#
#  flatten_1 (Flatten)         (None, 1024)                 0         ['conv2d_37[0][0]']
#
#  avg_pool_5_3x3/1 (GlobalAv  (None, 1024)                 0         ['inception_5b[0][0]']
#  eragePooling2D)
#
#  dense (Dense)               (None, 64)                   65600     ['flatten[0][0]']
#
#  dense_1 (Dense)             (None, 64)                   65600     ['flatten_1[0][0]']
#
#  dropout_2 (Dropout)         (None, 1024)                 0         ['avg_pool_5_3x3/1[0][0]']
#
#  dropout (Dropout)           (None, 64)                   0         ['dense[0][0]']
#
#  dropout_1 (Dropout)         (None, 64)                   0         ['dense_1[0][0]']
#
#  output (Dense)              (None, 10)                   10250     ['dropout_2[0][0]']
#
#  output_1 (Dense)            (None, 10)                   650       ['dropout[0][0]']
#
#  auxilliary_output_2 (Dense  (None, 10)                   650       ['dropout_1[0][0]']
#  )
#
# ==================================================================================================
# Total params: 2686958 (10.25 MB)
# Trainable params: 2686958 (10.25 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
tf.config.list_physical_devices()
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'),
#  PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
epochs = 20
initial_lrate = 0.01

def decay(epoch, steps=100):
    initial_lrate = 0.01
    drop = 0.96
    epochs_drop = 8
    lrate = initial_lrate * math.pow(drop, math.floor((1+epoch)/epochs_drop))
    return lrate

sgd = SGD(lr=initial_lrate, momentum=0.9, nesterov=False)

lr_sc = LearningRateScheduler(decay, verbose=1)

print(y_train[0])
model.compile(loss='sparse_categorical_crossentropy',
              loss_weights=[1, 0.3, 0.3],
              optimizer=sgd,
              metrics=['accuracy'])

history = model.fit(X_train, [y_train, y_train, y_train],
                    validation_data=(X_test, [y_test, y_test, y_test]),
                    epochs=epochs,
                    batch_size=256,
                    callbacks=[lr_sc])
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# [6]
#
# Epoch 1: LearningRateScheduler setting learning rate to 0.01.
# Epoch 1/20
# 4/4 [==============================] - 12s 847ms/step - loss: 3.6847 - output_loss: 2.3030 - output_1_loss: 2.3025 - auxilliary_output_2_loss: 2.3032 - output_accuracy: 0.1100 - output_1_accuracy: 0.0980 - auxilliary_output_2_accuracy: 0.0930 - val_loss: 3.6842 - val_output_loss: 2.3029 - val_output_1_loss: 2.3038 - val_auxilliary_output_2_loss: 2.3005 - val_output_accuracy: 0.0900 - val_output_1_accuracy: 0.0650 - val_auxilliary_output_2_accuracy: 0.1450 - lr: 0.0100
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.01.
# Epoch 2/20
# 4/4 [==============================] - 2s 522ms/step - loss: 3.6839 - output_loss: 2.3024 - output_1_loss: 2.3024 - auxilliary_output_2_loss: 2.3027 - output_accuracy: 0.0870 - output_1_accuracy: 0.1070 - auxilliary_output_2_accuracy: 0.1040 - val_loss: 3.6842 - val_output_loss: 2.3029 - val_output_1_loss: 2.3037 - val_auxilliary_output_2_loss: 2.3006 - val_output_accuracy: 0.0700 - val_output_1_accuracy: 0.0700 - val_auxilliary_output_2_accuracy: 0.1300 - lr: 0.0100
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.01.
# Epoch 3/20
# 4/4 [==============================] - 2s 535ms/step - loss: 3.6834 - output_loss: 2.3023 - output_1_loss: 2.3014 - auxilliary_output_2_loss: 2.3024 - output_accuracy: 0.0940 - output_1_accuracy: 0.1080 - auxilliary_output_2_accuracy: 0.1020 - val_loss: 3.6839 - val_output_loss: 2.3027 - val_output_1_loss: 2.3036 - val_auxilliary_output_2_loss: 2.3006 - val_output_accuracy: 0.0700 - val_output_1_accuracy: 0.0700 - val_auxilliary_output_2_accuracy: 0.1300 - lr: 0.0100
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.01.
# Epoch 4/20
#
# Epoch 16: LearningRateScheduler setting learning rate to 0.009216.
# Epoch 16/20
# 4/4 [==============================] - 2s 534ms/step - loss: 3.6772 - output_loss: 2.2988 - output_1_loss: 2.2956 - auxilliary_output_2_loss: 2.2991 - output_accuracy: 0.1120 - output_1_accuracy: 0.1160 - auxilliary_output_2_accuracy: 0.1000 - val_loss: 3.6823 - val_output_loss: 2.3021 - val_output_1_loss: 2.3012 - val_auxilliary_output_2_loss: 2.2996 - val_output_accuracy: 0.0700 - val_output_1_accuracy: 0.0700 - val_auxilliary_output_2_accuracy: 0.0950 - lr: 0.0092
#
# Epoch 17: LearningRateScheduler setting learning rate to 0.009216.
# Epoch 17/20
# 4/4 [==============================] - 2s 499ms/step - loss: 3.6770 - output_loss: 2.2987 - output_1_loss: 2.2971 - auxilliary_output_2_loss: 2.2975 - output_accuracy: 0.1120 - output_1_accuracy: 0.1080 - auxilliary_output_2_accuracy: 0.1330 - val_loss: 3.6819 - val_output_loss: 2.3018 - val_output_1_loss: 2.3010 - val_auxilliary_output_2_loss: 2.2994 - val_output_accuracy: 0.0700 - val_output_1_accuracy: 0.0700 - val_auxilliary_output_2_accuracy: 0.0950 - lr: 0.0092
#
# Epoch 18: LearningRateScheduler setting learning rate to 0.009216.
# Epoch 18/20
# 4/4 [==============================] - 2s 535ms/step - loss: 3.6759 - output_loss: 2.2984 - output_1_loss: 2.2940 - auxilliary_output_2_loss: 2.2976 - output_accuracy: 0.1120 - output_1_accuracy: 0.1280 - auxilliary_output_2_accuracy: 0.1090 - val_loss: 3.6811 - val_output_loss: 2.3015 - val_output_1_loss: 2.3002 - val_auxilliary_output_2_loss: 2.2987 - val_output_accuracy: 0.0700 - val_output_1_accuracy: 0.0700 - val_auxilliary_output_2_accuracy: 0.1000 - lr: 0.0092
#
# Epoch 19: LearningRateScheduler setting learning rate to 0.009216.
# Epoch 19/20
# 4/4 [==============================] - 2s 534ms/step - loss: 3.6755 - output_loss: 2.2977 - output_1_loss: 2.2958 - auxilliary_output_2_loss: 2.2968 - output_accuracy: 0.1120 - output_1_accuracy: 0.1050 - auxilliary_output_2_accuracy: 0.1190 - val_loss: 3.6807 - val_output_loss: 2.3012 - val_output_1_loss: 2.3000 - val_auxilliary_output_2_loss: 2.2983 - val_output_accuracy: 0.0700 - val_output_1_accuracy: 0.0700 - val_auxilliary_output_2_accuracy: 0.0950 - lr: 0.0092
#
# Epoch 20: LearningRateScheduler setting learning rate to 0.009216.
# Epoch 20/20
# 4/4 [==============================] - 2s 535ms/step - loss: 3.6739 - output_loss: 2.2975 - output_1_loss: 2.2925 - auxilliary_output_2_loss: 2.2954 - output_accuracy: 0.1120 - output_1_accuracy: 0.1220 - auxilliary_output_2_accuracy: 0.1310 - val_loss: 3.6799 - val_output_loss: 2.3008 - val_output_1_loss: 2.2994 - val_auxilliary_output_2_loss: 2.2978 - val_output_accuracy: 0.0700 - val_output_1_accuracy: 0.0700 - val_auxilliary_output_2_accuracy: 0.1050 - lr: 0.0092

# %% [markdown]
# * **Because of the limitations of RAM and GPU , we only used 2% of the whole dataset and we decreased number of Conv kernels as well , so dont expect high accuracy brothers and sister :)**
